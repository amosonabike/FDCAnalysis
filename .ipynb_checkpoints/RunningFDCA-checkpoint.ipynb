# %%
import sys
# # # INSERT YOUR PATH THE THE /FDCAnalysis FOLDER HERE # # #
sys.path.append('/Users/danhardy/OneDrive - University of Bristol/BARC Desktop/Python Porjects/FDC data processing/FDCAnalysis')
import FDCA

# %%
dryfilelocation, drymultifilelocation = FDCA.get_file_locations('SampleData00pctRH')
# Out:
# Found results file:  2021-11-10-Wed_1_Results.txt
# 	 at:  SampleData00pctRH/2021-11-10-Wed_1_Results.txt
#
# Found multiple exposure file:  2021-11-10-Wed_Multiple exposures - 2 exposures at 5000 us separation.txt
# 	 at:  SampleData00pctRH/2021-11-10-Wed_Multiple exposures - 2 exposures at 5000 us separation.txt

# %%
humidfilelocation, humidmultifilelocation = FDCA.get_file_locations('SampleData40pctRH')
# Out:
# Found results file:  2021-11-11-Thu_5_Results.txt
# 	 at:  SampleData40pctRH/2021-11-11-Thu_5_Results.txt
#
# Found multiple exposure file:  2021-11-11-Thu_Multiple exposures - 2 exposures at 5000 us separation.txt
# 	 at:  SampleData40pctRH/Multiple exposures/2021-11-11-Thu_Multiple exposures - 2 exposures at 5000 us separation.txt

# %%
dry_output_parameters, dry_results = FDCA.run_all_analysis(dryfilelocation, 1, 500, 1020)
# Out:
# Experimental Conditions:
#
#
# Temperature average, std. dev., min, max, gradient
#  22.512221700374518 0.09891199728181568 22.395815 22.737732 0.11397233333333408
#
# RH average, std. dev., min, max, gradient
#  2.032552147565537 0.18747993404934593 1.698319 2.627116 0.309599
# Warning: Min velocity is less than 0, check value of gas flow!
# 	Min value =  -43.85897435897395
# Warning: some d_a^2 values < 0. Check gas flow values and corrected velocity
#
# Retrieving Relaxation Period
# 	Using custom Reynolds treshold:  3
# total fit: Initial amplitude = 2439.368, Tau= 0.0037, Vertical offset= 17.232
# x fit: Initial amplitude = 2435.606, Tau= 0.0037, Vertical offset= -2.248
# y fit: Initial amplitude = 1772.360, Tau= 0.0007, Vertical offset= 25.336
# Starting density ratio (da^2 * rho_water) / (de^2 * rho_solution):  1.8397697991339825
#  Gas flow correction factor =  0.963
# /Users/danhardy/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  Gas flow correction factor =  0.0009999999999991188Could not find correction factor, setting to 0
#
# Estimated gas flow in column (sccm):  0
# Final density ratio (da^2 * rho_water) / (de^2 * rho_solution):  0.9749717647202963
# Warning: some d_a^2 values < 0. Check gas flow values and corrected velocity
#
# Retrieving Relaxation Period
# 	Using custom Reynolds treshold:  3
# total fit: Initial amplitude = 2460.986, Tau= 0.0036, Vertical offset= 34.754
# x fit: Initial amplitude = 2435.606, Tau= 0.0037, Vertical offset= -2.248
# y fit: Initial amplitude = 1772.151, Tau= 0.0007, Vertical offset= 46.169
# /Users/danhardy/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# good fit
# Fitted intial size / µm			42.751
# Calculated eavporation rate / µm^2/s	3192.972
# R squared				1.0

# %%
humid_output_parameters, humid_results = FDCA.run_all_analysis(humidfilelocation, 1, 500, 1020)
# Out:
# Experimental Conditions:
#
#
# Temperature average, std. dev., min, max, gradient
#  23.888538332647098 0.08062867899171779 23.794985 24.099342 0.10145233333333319
#
# RH average, std. dev., min, max, gradient
#  40.514291624117504 0.18466448124718277 40.088583 41.120579 0.3439986666666665
# Warning: Min velocity is less than 0, check value of gas flow!
# 	Min value =  -14.828700980392362
# Warning: some d_a^2 values < 0. Check gas flow values and corrected velocity
#
# Retrieving Relaxation Period
# 	Using custom Reynolds treshold:  3
# total fit: Initial amplitude = 1439.764, Tau= 0.0040, Vertical offset= 7.968
# x fit: Initial amplitude = 1436.555, Tau= 0.0042, Vertical offset= -7.365
# y fit: Initial amplitude = 181.601, Tau= 0.0018, Vertical offset= 29.241
# Starting density ratio (da^2 * rho_water) / (de^2 * rho_solution):  1.6918812546588826
#  Gas flow correction factor =  0.948
# /Users/danhardy/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  Gas flow correction factor =  0.07399999999999918as flow correction factor =  0.7089999999999997
# Estimated gas flow in column (sccm):  36.99999999999959
# Final density ratio (da^2 * rho_water) / (de^2 * rho_solution):  0.9991260486044008
#
# Retrieving Relaxation Period
# 	Using custom Reynolds treshold:  3
# total fit: Initial amplitude = 1433.130, Tau= 0.0039, Vertical offset= 24.556
# x fit: Initial amplitude = 1436.555, Tau= 0.0042, Vertical offset= -7.365
# y fit: Initial amplitude = 181.601, Tau= 0.0018, Vertical offset= 48.532
# good fit
# Fitted intial size / µm			37.423
# Calculated eavporation rate / µm^2/s	675.749
# R squared				0.992

# %%
dry_ME_results = FDCA.get_multiple_exposure_data(drymultifilelocation,
                                                 dry_output_parameters['CalculatedGasFlow'])

# %%
humid_ME_results = FDCA.get_multiple_exposure_data(humidmultifilelocation,
                                                   humid_output_parameters['CalculatedGasFlow'])

# %%
FDCA.generate_plots(dry_results,
                    dry_output_parameters,
                    colour = 'magenta',
                    multi_exposure_dict=dry_ME_results,
                    rolling_window=7)

FDCA.generate_plots(humid_results,
                    humid_output_parameters,
                    colour = 'lime',
                    multi_exposure_dict=humid_ME_results,
                    rolling_window=7)

# %%
rh_list = [0,
           40]

results_list = [dry_results,
                humid_results]

multi_list = [dry_ME_results,
              humid_ME_results]

# %%
FDCA.plot_RH_comparison(results_list,
                        rh_list,
                        multi_list,
                        7,
                        'magenta',
                        'cyan')
